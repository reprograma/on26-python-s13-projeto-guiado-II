# %%
import csv
import sqlite3

# %%
file = open("nation_1751_2017.csv")

# %%
conteudo = csv.reader(file)

connection = sqlite3.connect("emissoes_serie_historica.db")

cursor = connection.cursor()

# %%
cursor.execute('''CREATE TABLE IF NOT EXISTS nation (
    'Nation' VARCHAR,
    'Year' INT,
    'Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)' INT, 
    'Emissions from solid fuel consumption' INT,
    'Emissions from liquid fuel consumption' INT,
    'Emissions from gas fuel consumption' INT,
    'Emissions from cement production' INT,
    'Emissions from gas flaring' INT,
    'Per capita CO2 emissions (metric tons of carbon)' INT,
    'Emissions from bunker fuels (not included in the totals)' INT

)''')

# %%
inserir_conteudo = "INSERT INTO nation ('Nation','Year','Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)','Emissions from solid fuel consumption','Emissions from liquid fuel consumption','Emissions from gas fuel consumption','Emissions from cement production','Emissions from gas flaring','Per capita CO2 emissions (metric tons of carbon)','Emissions from bunker fuels (not included in the totals)')VALUES(?, ?, ?, ?, ?, ?, ?, ?, ?, ?)"

cursor.executemany(inserir_conteudo, conteudo)

# %%
selecionar_tudo = "SELECT * FROM nation"
entradas = cursor.execute(selecionar_tudo).fetchall()

# %%
for entrada in entradas:
  print(entrada)
# Out:
# ('Nation', 'Year', 'Total CO2 emissions from fossil-fuels and cement production (thousand metric tons of C)', 'Emissions from solid fuel consumption', 'Emissions from liquid fuel consumption', 'Emissions from gas fuel consumption', 'Emissions from cement production', 'Emissions from gas flaring', 'Per capita CO2 emissions (metric tons of carbon)', 'Emissions from bunker fuels (not included in the totals)')
# ('AFGHANISTAN ', 1949, 4, 4, 0, 0, 0, '. ', '. ', 0)
# ('AFGHANISTAN ', 1950, 23, 6, 18, 0, 0, 0, 0, 0)
# ('AFGHANISTAN ', 1951, 25, 7, 18, 0, 0, 0, 0, 0)
# ('AFGHANISTAN ', 1952, 25, 9, 17, 0, 0, 0, 0, 0)
# ('AFGHANISTAN ', 1953, 29, 10, 18, 0, 0, 0, 0, 0)
# ('AFGHANISTAN ', 1954, 29, 12, 18, 0, 0, 0, 0, 0)
# ('AFGHANISTAN ', 1955, 42, 17, 25, 0, 0, 0, 0.01, 0)
# ('AFGHANISTAN ', 1956, 50, 17, 33, 0, 0, 0, 0.01, 0)
# ('AFGHANISTAN ', 1957, 80, 21, 59, 0, 0, 0, 0.01, 0)
# ('AFGHANISTAN ', 1958, 90, 25, 65, 0, 0, 0, 0.01, 0)
# ('AFGHANISTAN ', 1959, 105, 30, 70, 0, 5, 0, 0.01, 0)
# ...

# %%
connection.commit()
connection.close()
