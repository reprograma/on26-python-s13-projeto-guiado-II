# %%
import pandas as pd
import matplotlib

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\Webfoco\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import sqlite3

# %%
connection = sqlite3.connect("populacaorua.db")

# %%
cursor = connection.cursor()
cursor.execute('''
    CREATE TABLE IF NOT EXISTS minha_tabela (
        id INTEGER PRIMARY KEY,
        nome TEXT,
        idade INTEGER,
        orientacao_sexual TEXT
    )
''')

# %%
df = pd.read_csv('populacao.rua.csv')
df
# Out:
#     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0          NaN  Disque 100 - Ano 2011 - População Situação de ...        NaN
# 1          NaN                                               Sexo        JAN
# 2          NaN                                           Feminino         15
# 3          NaN                                          Masculino         43
# 4          NaN                                      Não Informado          4
# ..         ...                                                ...        ...
# 61         NaN                                      Não Informada        NaN
# 62         NaN                             Não possui deficiência         54
# 63         NaN                                             Visual        NaN
# 64         NaN                                              Total         62
# 65         NaN  *Obs: Estão sendo consideradas todas as defici...        NaN
#
# ...

# %%
df.sort_values
# Out:
# <bound method DataFrame.sort_values of     Unnamed: 0                                         Unnamed: 1 Unnamed: 2  \
# 0          NaN  Disque 100 - Ano 2011 - População Situação de ...        NaN
# 1          NaN                                               Sexo        JAN
# 2          NaN                                           Feminino         15
# 3          NaN                                          Masculino         43
# 4          NaN                                      Não Informado          4
# ..         ...                                                ...        ...
# 61         NaN                                      Não Informada        NaN
# 62         NaN                             Não possui deficiência         54
# 63         NaN                                             Visual        NaN
# 64         NaN                                              Total         62
# 65         NaN  *Obs: Estão sendo consideradas todas as defici...        NaN
#
# ...

# %%
df = df.dropna()


df
# Out:
# Empty DataFrame
# ...

# %%
df = df.dropna
