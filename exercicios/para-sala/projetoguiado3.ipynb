# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("demolitions_pse_isr_conflict_2004-01_to_2023-08.csv", sep="," , encoding= 'UTF-8')

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.shape
# Out:
# (5765, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5765 entries, 0 to 5764
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date_of_demolition     5765 non-null   object
#  1   locality               5763 non-null   object
#  2   district               5763 non-null   object
#  3   area                   5765 non-null   object
#  4   housing_units          5765 non-null   int64
#  5   people_left_homeless   5765 non-null   int64
#  6   minors_left_homeless   5765 non-null   int64
#  7   type_of_sturcture      5765 non-null   object
#  8   reason_for_demolition  5765 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 405.5+ KB

# %%
# impressão dos dez primeiros
df.head(10)
# Out:
#   date_of_demolition              locality district       area  housing_units  \
# 0         2023-08-30              Tarqumya   Hebron  west-bank              2
# 1         2023-08-29            al-Bweirah   Hebron  west-bank              1
# 2         2023-08-24                Shufah  Tulkarm  west-bank              1
# 3         2023-08-21                  Bidu  al-Quds  west-bank              8
# 4         2023-08-21                  Bidu  al-Quds  west-bank              3
# 5         2023-08-21  'Ein a-Duyuk a-Tahta  Jericho  west-bank              1
# 6         2023-08-21                  Bidu  al-Quds  west-bank              1
# 7         2023-08-21  'Ein a-Duyuk a-Tahta  Jericho  west-bank              1
# 8         2023-08-21  'Ein a-Duyuk a-Tahta  Jericho  west-bank              1
# 9         2023-08-21  'Ein a-Duyuk a-Tahta  Jericho  west-bank              1
#
#    people_left_homeless  minors_left_homeless type_of_sturcture  \
# 0                     0                     0   Non Resedential
# 1                     0                     0        Residental
# 2                     0                     0   Non Resedential
# 3                     0                     0   Non Resedential
# 4                     0                     0   Non Resedential
# 5                     0                     0        Residental
# 6                     0                     0        Residental
# 7                     8                     0        Residental
# 8                     8                     3        Residental
# 9                     0                     0        Residental
#
#                                reason_for_demolition
# 0  Demolition on the pretext of unlawful construc...
# 1  Demolition on the pretext of unlawful construc...
# 2  Demolition on the pretext of unlawful construc...
# 3  Demolition on the pretext of unlawful construc...
# 4  Demolition on the pretext of unlawful construc...
# 5  Demolition on the pretext of unlawful construc...
# 6  Demolition on the pretext of unlawful construc...
# 7  Demolition on the pretext of unlawful construc...
# 8  Demolition on the pretext of unlawful construc...
# 9  Demolition on the pretext of unlawful construc...

# %%
df = df.dropna(how='any')

# %%
soma_coluna = df['housing_units'].sum()

# Crie um gráfico de barras com a soma da coluna
plt.bar('housing_units', soma_coluna)
plt.title('Soma da Coluna "Unidades Habitacionais"')
plt.xlabel('Categoria')
plt.ylabel('Soma')
plt.show()

# %%
soma_coluna1 = df['people_left_homeless'].sum()
soma_coluna2 = df['minors_left_homeless'].sum()

# Crie um gráfico de barras para as somas
categorias = ['people_left_homeless', 'minors_left_homeless']
somas = [soma_coluna1, soma_coluna2]

plt.bar(categorias, somas)
plt.title('Soma das Colunas Adultos/Idosos e Menores Desabrigados')
plt.xlabel('Categoria')
plt.ylabel('Soma')
plt.show()

# %%
contagem_reason = df['reason_for_demolition'].value_counts()
razoes_mais_frequentes = 3
contagem_reason = contagem_reason.head(razoes_mais_frequentes)

plt.bar(contagem_reason.index, contagem_reason)
plt.title('"Razões" alegadas com frequência')
plt.xlabel('Razões')
plt.ylabel('Contagem')
plt.xticks(rotation=90)  # Rotação dos rótulos no eixo x para facilitar a leitura
plt.show()
